# %% [markdown]
# # TKO Tumor Preprocessing

# %%
# import mazebox as mb
import scvelo as scv
import scanpy as sc
import os.path as op
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sys
import dropkick as dk
# make sure to use position 1
sys.path.insert(1, "/Users/smgroves/Documents/GitHub/Groves-CellSys2021/")
import mazebox as mb
import cellrank as cr
import scanorama

# %% [markdown]
# ## Read in Files

# %%
indir = "../../../data/single-cell-rna-seq/TKO-tumors/"

samples = ['TKO1','TKO2','TKO3']
[a1,a2,a3] = [mb.pp.read_loom(sample, indir) for sample in samples]
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
tfs = ['SP100', 'FOSL1', 'HES1', 'NFKBIZ', 'RELB', 'EPAS1', 'BCL3', 'REST', 'SP110', 'NFKB2', 'TEAD2', 'HMG20B', 'SIX5',
       'RARG', 'TEAD4', 'ZNF217', 'SP140L', 'SOX18', 'HOXC13', 'STAT6', 'ETV4', 'KLF2', 'MITF', 'NR0B2', 'ASCL1', 'ZBTB7C', 'ELF3',
       'RORC', 'FOXA2', 'ETS2','TOX3', 'XBP1', 'ST18', 'FOXA1', 'OVOL2', 'ZNF664', 'TBX10', 'PROX1', 'ETV6', 'CEBPD', 'TFCP2L1', 'FOXJ3',
       'ZNF407', 'ZNF511','ZNF396', 'RBPJ', 'ZSCAN31', 'HOXB5', 'ZNF3', 'TSHZ2', 'ZBTB16', 'ZNF10', 'FLI1', 'GATA4', 'NR0B1', 'NHLH1',
       'NEUROD6', 'ZNF581', 'TCF15', 'LYAR', 'ISL2', 'OLIG2', 'NEUROD1', 'INSM1', 'PAX5', 'SP6', 'MYT1', 'HES6', 'ZNF24', 'ISL1', 'ZNF397',
       'SOX11', 'ZNF253', 'SMAD4', 'RBP1', 'ONECUT2', 'ZNF711', 'DLX5', 'GRIP1', 'ZNF157', 'ZNF713', 'ZNF136', 'FOXN4', 'PATZ1', 'ZNF491',
       'ZBTB21', 'KLF12', 'ZNF501', 'ZNF785', 'CXXC1', 'ZNF324', 'ZNF764', 'ZBTB18', 'KAT8', 'ZNF334', 'POU4F1', 'ZNF250', 'ZNF132',
       'SALL2', 'DLX6', 'MBD1','SOX1', 'ZFP3', 'ZNF543', 'POU2F1', 'NONO', 'SMAD9', 'ZKSCAN2', 'TCF12', 'VEZF1', 'TOX', 'BHLHE22', 'MTA1',
       'TCF3', 'SCRT2', 'RFX7','NHLH2', 'SCRT1', 'RCOR2', 'PURG', 'TBPL1', 'TCF4', 'EBF1', 'ZNF749', 'NEUROD2', 'ZNF423', 'BACH2', 'GLI1',
       'ZFP64','NKX2-1', 'MYC', 'YAP1', 'POU2F3', 'MYCL', 'MYCN', 'ASCL2', 'AVIL', 'CHAT', 'GFI1B',
      'CHGA','EPCAM']

# %% [markdown]
# ## Dropkick

# %% [markdown]
# How many cells in each dataset?

# %%
total_cells = 0
for i,a in enumerate([a1,a2, a3]):
    print(samples[i])
    print(a.X.shape)
    total_cells += a.X.shape[0]
print("Total cells: ", total_cells)
# Out:
# TKO1
# (4514, 27998)
# TKO2
# (3816, 27998)
# TKO3
# (3898, 27998)
# Total cells:  12228

# %%
ax = a3.copy()
sc.pp.filter_cells(ax, min_genes=100)

# %%
ax
# Out:
# AnnData object with n_obs × n_vars = 3898 × 27998
#     obs: 'dropkick_score', 'dropkick_label', 'arcsinh_n_genes_by_counts', 'n_genes'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'dropkick_coef'
#     uns: 'dropkick_thresholds', 'dropkick_args'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
batch_categories = ['TKO1','TKO2','TKO3']
batch_key = 'tumor'

adatas = [a1,a2,a3]


adata = mb.pp.dropkick_recipe(adatas, verbose=False, filter=False, batch_categories = batch_categories, batch_key = batch_key,
                                                X_final = 'log1p_norm',plot = False, n_hvgs=None, min_genes=500, min_counts=3,
                                                retain_genes=tfs)
# Out:
# Running dropkick on each sample and filtering...
# Chosen lambda value:
# 	[0.10492838]
# Assigning scores and labels
# Done!
#
# Chosen lambda value:
# 	[0.0883452]
# Assigning scores and labels
# Done!
#
# Chosen lambda value:
# 	[0.10233253]
# Assigning scores and labels
# Done!
#
# AnnData object with n_obs × n_vars = 12228 × 27998
#     obs: 'dropkick_score', 'dropkick_label', 'arcsinh_n_genes_by_counts', 'tumor'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'dropkick_coef-TKO1', 'dropkick_coef-TKO2', 'dropkick_coef-TKO3'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'
# Filtering and normalizing concatenated data...
# Filtered out 12555 genes that are detected 3 counts (spliced).
# AnnData object with n_obs × n_vars = 12220 × 15443
#     obs: 'dropkick_score', 'dropkick_label', 'arcsinh_n_genes_by_counts', 'tumor', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'dropkick_coef-TKO1', 'dropkick_coef-TKO2', 'dropkick_coef-TKO3'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced', 'raw_counts'
# calculating cell cycle phase
# -->     'S_score' and 'G2M_score', scores of cell cycle phases (adata.obs)

# %%
scv.pp.neighbors(adata, random_state=0)
scv.tl.umap(adata, random_state=0)
# Out:
# computing neighbors
#     finished (0:00:11) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 12220 × 15443
#     obs: 'dropkick_score', 'dropkick_label', 'arcsinh_n_genes_by_counts', 'tumor', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ambient', 'log1p_total_counts_ambient', 'pct_counts_ambient', 'arcsinh_total_counts', 'S_score', 'G2M_score', 'phase'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'dropkick_coef-TKO1', 'dropkick_coef-TKO2', 'dropkick_coef-TKO3', 'mito', 'pct_dropout_by_counts', 'ambient', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std'
#     uns: 'neighbors', 'pca', 'tumor_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'ambiguous', 'arcsinh_norm', 'log1p_norm', 'matrix', 'raw_counts', 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
scv.pl.umap(adata, color = ['dropkick_score','tumor', 'pct_counts_mito'], legend_loc = 'on right')

# %%
adata.write_h5ad('../../out/TKO-tumors/adata_01.h5ad')

# %% [markdown]
# In my dropkick recipe, setting filter = False will add the dropkick labels/scores to adata but does not actually filter any cells or genes. It **will** filter cells and genes based on scanpy's and scvelo's functions:
# `sc.pp.filter_cells(adata, min_genes=min_genes);
# scv.pp.filter_genes(adata, min_counts=min_counts, retain_genes=retain_genes)`

# %%
adata = sc.read_h5ad('../../out/TKO-tumors/adata_01.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 12220 × 15443
#     obs: 'dropkick_score', 'dropkick_label', 'arcsinh_n_genes_by_counts', 'tumor', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ambient', 'log1p_total_counts_ambient', 'pct_counts_ambient', 'arcsinh_total_counts', 'S_score', 'G2M_score', 'phase'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'dropkick_coef-TKO1', 'dropkick_coef-TKO2', 'dropkick_coef-TKO3', 'mito', 'pct_dropout_by_counts', 'ambient', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std'
#     uns: 'neighbors', 'pca', 'tumor_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'ambiguous', 'arcsinh_norm', 'log1p_norm', 'matrix', 'raw_counts', 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
adata_dk = adata[adata.obs.dropkick_label=='True'].copy() #if this throws an error or gives 0 cells, try ==1 or == True

# %%
scv.pp.pca(adata_dk, random_state=0)

# %%
scv.pl.pca(adata_dk, color = ['dropkick_score','tumor'], legend_loc = 'on right', frameon=True)

# %%
scv.pp.neighbors(adata_dk, random_state=0)
scv.tl.umap(adata_dk, random_state=0)
# Out:
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)

# %%
scv.pl.umap(adata_dk, color = ['tumor'], legend_loc = 'on right')

# %%
adata_dk.write_h5ad('../../out/TKO-tumors/adata_dk_01.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 12220 × 15443
#     obs: 'dropkick_score', 'dropkick_label', 'arcsinh_n_genes_by_counts', 'tumor', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ambient', 'log1p_total_counts_ambient', 'pct_counts_ambient', 'arcsinh_total_counts', 'S_score', 'G2M_score', 'phase'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'dropkick_coef-TKO1', 'dropkick_coef-TKO2', 'dropkick_coef-TKO3', 'mito', 'pct_dropout_by_counts', 'ambient', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std'
#     uns: 'neighbors', 'pca', 'tumor_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'ambiguous', 'arcsinh_norm', 'log1p_norm', 'matrix', 'raw_counts', 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
adata_dk
# Out:
# AnnData object with n_obs × n_vars = 2310 × 15443
#     obs: 'dropkick_score', 'dropkick_label', 'arcsinh_n_genes_by_counts', 'tumor', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ambient', 'log1p_total_counts_ambient', 'pct_counts_ambient', 'arcsinh_total_counts', 'S_score', 'G2M_score', 'phase'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'dropkick_coef-TKO1', 'dropkick_coef-TKO2', 'dropkick_coef-TKO3', 'mito', 'pct_dropout_by_counts', 'ambient', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std'
#     uns: 'neighbors', 'pca', 'tumor_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'ambiguous', 'arcsinh_norm', 'log1p_norm', 'matrix', 'raw_counts', 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ## Doublet detection

# %% [markdown]
# Given a raw (unnormalized) UMI counts matrix counts_matrix with cells as rows and genes as columns, calculate a doublet score for each cell:
#
# ```import scrublet as scr
# scrub = scr.Scrublet(counts_matrix)
# doublet_scores, predicted_doublets = scrub.scrub_doublets()
# scr.scrub_doublets() simulates doublets from the observed data and uses a k-nearest-neighbor classifier to calculate a continuous doublet_score (between 0 and 1) for each transcriptome. The score is automatically thresholded to generate predicted_doublets, a boolean array that is True for predicted doublets and False otherwise.
# ```
# Best practices:
# - When working with data from multiple samples, run Scrublet on each sample separately. Because Scrublet is designed to detect technical doublets formed by the random co-encapsulation of two cells, it may perform poorly on merged datasets where the cell type proportions are not representative of any single sample.
# - Check that the doublet score threshold is reasonable (in an ideal case, separating the two peaks of a bimodal simulated doublet score histogram, as in this example), and adjust manually if necessary.
# - Visualize the doublet predictions in a 2-D embedding (e.g., UMAP or t-SNE). Predicted doublets should mostly co-localize (possibly in multiple clusters). If they do not, you may need to adjust the doublet score threshold, or change the pre-processing parameters to better resolve the cell states present in your data.

# %%
for a in [a1,a2,a3]:
    mb.pp.doublet_detections(a, layer = 'matrix')
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 5.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 4.7%
# Elapsed time: 3.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 2.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.19
# Detected doublet rate = 27.0%
# Estimated detectable doublet fraction = 59.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 45.3%
# Elapsed time: 2.4 seconds

# %%
(a1.obs.predicted_doublets == True).sum()
# Out:
# 11

# %%
(set(a1[a1.obs.predicted_doublets == True].obs_names).intersection(set([i.split('-')[0] for i in adata_dk.obs_names])))
# Out:
# {'TK01:CTAAACCTACGTTGx'}

# %%
(a2.obs.predicted_doublets == True).sum()
# Out:
# 0

# %%
(a3.obs.predicted_doublets == True).sum()
# Out:
# 1052

# %%
print("Doublets still left in filtered data")
len(set(a3[a3.obs.predicted_doublets == True].obs_names).intersection(set([i.split('-')[0] for i in adata_dk.obs_names])))
# Out:
# Doublets still left in filtered data
# 479

# %%
import scrublet as scr
scrub = scr.Scrublet(a3.layers['matrix'])
doublet_scores, predicted_doublets = scrub.scrub_doublets()
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.19
# Detected doublet rate = 27.0%
# Estimated detectable doublet fraction = 59.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 45.3%
# Elapsed time: 2.2 seconds

# %%
scrub.plot_histogram();

# %%
print('Running UMAP...')
scrub.set_embedding('UMAP', scr.get_umap(scrub.manifold_obs_, 10, min_dist=0.3))

# # Uncomment to run tSNE - slow
# print('Running tSNE...')
# scrub.set_embedding('tSNE', scr.get_tsne(scrub.manifold_obs_, angle=0.9))

# # Uncomment to run force layout - slow
# print('Running ForceAtlas2...')
# scrub.set_embedding('FA', scr.get_force_layout(scrub.manifold_obs_, n_neighbors=5. n_iter=1000))
    
print('Done.')
# Out:
# Running UMAP...
# Done.

# %%
scrub.plot_embedding('UMAP', order_points=True);

# %% [markdown]
# I think the doublets above are not true doublets, because
# 1. The histogram is not bimodal.
# 2. The predicted doublets do not cluster, but instead fall in the center of the data.
# 3. I would not expect this tumor to have significantly more doublets than other tumors.
# 4. Scrublet can only detect neotypic doublets. Therefore, since this sample is very homogeneous, it is not finding any neotypic doublets because it does not have different cell type mixes to simulate.

# %%
scrub_log = scr.Scrublet(a3)
doublet_scores_log, predicted_doublets_log = scrub_log.scrub_doublets(n_prin_comps=30, 
                                                                      mean_center=False, 
                                                                      normalize_variance=False,
                                                                      log_transform=True
                                                                     )

# %%
scrub_log.plot_histogram();

# %%
print('Running UMAP...')
scrub_log.set_embedding('UMAP', scr.get_umap(scrub_log.manifold_obs_, 10, min_dist=0.3))

# # Uncomment to run tSNE - slow
# print('Running tSNE...')
# scrub.set_embedding('tSNE', scr.get_tsne(scrub.manifold_obs_, angle=0.9))

# # Uncomment to run force layout - slow
# print('Running ForceAtlas2...')
# scrub.set_embedding('FA', scr.get_force_layout(scrub.manifold_obs_, n_neighbors=5. n_iter=1000))
    
print('Done.')

# %%
scrub_log.plot_embedding('UMAP', order_points=True);

# %% [markdown]
# ## EMT Signature

# %%
adata = sc.read_h5ad('../../out/TKO-tumors/adata_dk_01.h5ad')

# %%
emt = pd.read_csv('../../../data/single-cell-rna-seq/Lung EMT signature.csv', header = 0, index_col = 0)

# %%
sc.tl.score_genes(adata, gene_list=[i.capitalize() for i in emt.loc[emt['Group']=='M'].index], score_name='M')
sc.tl.score_genes(adata, gene_list=[i.capitalize() for i in emt.loc[emt['Group']=='E'].index], score_name='E')
# Out:
# WARNING: genes are not in var_names and ignored: ['Eppk1', 'Gpr56', 'Ankrd22', 'Prss22', 'C1orf172', 'C1orf116', 'Gpr110']

# %%
scv.pl.umap(adata, color_gradients=['E','M'], smooth = True, perc = [5,95], dpi = 200, colorbar = True)

# %% [markdown]
# ## Cell cycle regression

# %%
# dropkick recipe already scores cell cycle genes
sc.pl.umap(adata, color=['phase','tumor'])

# %%
sc.pl.scatter(adata, color=['phase','tumor'], basis = 'pca')

# %%
adata.obs["cell_cycle_diff"] = adata.obs["S_score"] - adata.obs["G2M_score"]

# %%
from matplotlib.colors import CenteredNorm 
sc.pl.umap(adata, color=['cell_cycle_diff', 'tumor'], cmap = 'RdBu', norm=CenteredNorm(0))

# %%
# sc.pp.regress_out(adata, ['S_score', 'G2M_score'])
# sc.pp.scale(adata)

# %%
# sc.pp.neighbors(adata, random_state=0)
# sc.tl.leiden(adata)
# Out:
# WARNING: You’re trying to run this on 18265 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %% [markdown]
# ## Saving

# %% [markdown]
# Because we filtered out the dropkick cells after filtering cells and genes with scanpy, we need to doublecheck that all of the genes are actually expressed in the dataset, so we'll do a small filter to get rid of any genes we missed.

# %%
sc.pp.filter_genes(adata, min_cells=3)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2310 × 12751
#     obs: 'dropkick_score', 'dropkick_label', 'arcsinh_n_genes_by_counts', 'tumor', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ambient', 'log1p_total_counts_ambient', 'pct_counts_ambient', 'arcsinh_total_counts', 'S_score', 'G2M_score', 'phase', 'M', 'E', 'clusters_gradients', 'cell_cycle_diff'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'dropkick_coef-TKO1', 'dropkick_coef-TKO2', 'dropkick_coef-TKO3', 'mito', 'pct_dropout_by_counts', 'ambient', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std', 'n_cells'
#     uns: 'neighbors', 'pca', 'tumor_colors', 'umap', 'clusters_gradients_colors', 'phase_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'ambiguous', 'arcsinh_norm', 'log1p_norm', 'matrix', 'raw_counts', 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
adata.write_h5ad('../../out/TKO-tumors/adata_dk_01.h5ad')

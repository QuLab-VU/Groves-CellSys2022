# %% [markdown]
# # Human Cell Lines

# %%
# import mazebox as mb
import scvelo as scv
import scanpy as sc
import os.path as op
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sys
import dropkick as dk
# make sure to use position 1
sys.path.insert(1, "/Users/smgroves/Documents/GitHub/Groves-CellSys2021/")
import mazebox as mb
import cellrank as cr
import scanorama

# %%
adata = cr.read('../../out/human-tumors/adata_02.h5ad')
# Out:
# /Users/smgroves/Documents/anaconda3/envs/mazebox_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `cellrank.tl.read` will be removed in version `2.0`. Please use the `cellrank.kernels` or `cellrank.estimators` interface instead.
#   """Entry point for launching an IPython kernel.

# %%
X_magic = cr.read('../../out/human-tumors/X_magic_02.h5ad')
X_magic
# Out:
# /Users/smgroves/Documents/anaconda3/envs/mazebox_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `cellrank.tl.read` will be removed in version `2.0`. Please use the `cellrank.kernels` or `cellrank.estimators` interface instead.
#   """Entry point for launching an IPython kernel.
# AnnData object with n_obs × n_vars = 1618 × 13938
#     obs: 'dropkick_score', 'dropkick_label', 'arcsinh_n_genes_by_counts', 'tumor', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ambient', 'log1p_total_counts_ambient', 'pct_counts_ambient', 'arcsinh_total_counts', 'S_score', 'G2M_score', 'phase', 'leiden', 'PTPRC+', 'COL1A1+', 'M', 'E', 'clusters_gradients', 'cell_cycle_diff', 'specialists_pca_diffdist'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'dropkick_coef-Tumor 1', 'dropkick_coef-Tumor 2', 'mito', 'pct_dropout_by_counts', 'ambient', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std', 'n_cells'
#     uns: 'pca', 'specialists_pca_diffdist_colors', 'tumor_colors'
#     obsm: 'X_pca', 'arc_distance'
#     varm: 'PCs'

# %%
adata.layers['imputed'] = X_magic.X
adata.obsm['X_pca_imputed'] = X_magic.obsm['X_pca']

# %%
adata.write_h5ad('../../out/human-tumors/adata_03.h5ad')

# %% [markdown]
# # Subtyping with Archetype Signatures

# %%
adata = cr.read('../../out/human-tumors/adata_03.h5ad')
# Out:
# /Users/smgroves/Documents/anaconda3/envs/mazebox_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `cellrank.tl.read` will be removed in version `2.0`. Please use the `cellrank.kernels` or `cellrank.estimators` interface instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Using Mazebox to generate archetype scores

# %%
sig_matrix = pd.read_csv('../../out/bulk/sig_matrix_ParTI_2021.csv', header =0, index_col = 0)

sig_matrix = sig_matrix / np.linalg.norm(sig_matrix, axis=0)

# %%
# import seaborn as sns
# max_subtype = []
# max_v = []
# sig_matrix_copy = sig_matrix.copy()
# for i,r in sig_matrix.iterrows():
#     maxi = r.idxmax()
#     maxv = r.max()
#     max_subtype.append(maxi) 
#     max_v.append(maxv)
# sig_matrix_copy['max_subtype'] = max_subtype
# sig_matrix_copy['max'] = max_v

# plt.figure(figsize=(5,30))
# sig_matrix_copy = sig_matrix_copy.sort_values(by = ['max_subtype','max'], ascending=[True, False])
# sig_matrix_copy = sig_matrix_copy[['SCLC-A','SCLC-A2','SCLC-N','SCLC-P','SCLC-Y']]
# sns.heatmap(sig_matrix_copy, cmap='viridis', yticklabels = True)
# plt.xticks(rotation = 90)
# plt.title(f'Log-transformed Archetype Expression Profiles')
# plt.tight_layout()
# # plt.savefig(op.join(outdir,f'figures/Archetypes/sig_matrix_logfc.pdf'))
# plt.show()
# plt.close()

# sig_matrix_copy.to_csv('../data/sig_matrix_ParTI.csv')

# %% [markdown]
# If the below code gives an error about data shape, use `type = 'csr'`.

# %% [markdown]
# Cells with zero expression for all genes in gene signature will get scores of NaN when assigning scores in adata.obs (because these cells are filtered for the calculation).

# %%
adata, adata_small, sig_matrix2 = mb.ar.phenotyping_recipe(adata, sig_matrix, groupby = 'tumor',velocity=False)
# Out:
# Trying to set attribute `.obs` of view, copying.
# Transforming tumor data...
# Gene signature matrix now has shape:  (79, 5)
# Tumor data shortened to genes in gene list...
# (1573, 79)
# Tumor data subsetting complete.

# %%
from sklearn.manifold import LocallyLinearEmbedding
def _archetype_diagram_no_arrows(_adata, score_name, color, figsize, order, multiplier,fname,
                                 sizes = None, alpha = .3, s = 30, color_dict = None, norm = 'scale'):
    # X = subtype scores for each subtype (pd dataframe)
    n_samples = len(_adata.obs_names)

    n_types = len(sig_matrix.columns)
    subtypes = sig_matrix.columns
    X = _adata.obs[[f"{x}{score_name}" for x in subtypes]]
    top = X.sum().sort_values(ascending=False)[:3]  # return a list of n largest element
    print(top.index)

    # normalize X to sum to 1 (makes sure that the data fits within the archetype diagram with I matrix = vertices
    X_norm = pd.DataFrame(columns=X.columns)
    if norm == 'scale':
        for i, r in X.iterrows():
            if r.sum() == 0:
                X_norm = X_norm.append(r)
            else:
                X_norm = X_norm.append(r / r.sum())
    elif norm == 'max':
        max = X.max().max()
        X_norm = X / max
    elif norm == 'None':
        X_norm = X

    X = X_norm.fillna(0)
    if type(order) != type(None):
        X = X[[f"{x}{score_name}" for x in order]]
        subtypes = order
    else:
        order = subtypes

    ident = np.identity(n_types)
    for i, x in enumerate(subtypes):
        X = X.append(pd.DataFrame(np.array(ident[i]), index=X.columns, columns=[x]).T)

    embedding = LocallyLinearEmbedding(n_components=2, n_neighbors=4, method='modified', eigen_solver='dense')
    X_transformed = embedding.fit_transform(X[-n_types:])
    X_transformed = X_transformed.T

    X_df_data = embedding.transform(X[:-n_types])
    X_df_data = X_df_data.T

    fig = plt.figure(figsize=figsize)

    ax = fig.add_subplot()
    colors = _adata.obs[color].values
    if type(colors[0]) == str:
        c = [color_dict[i] for i in colors]
    else:
        c = colors
    plt.scatter(X_df_data[0], X_df_data[1], c=c, zorder=1, alpha=alpha, s=s)
    if type(sizes) == int:
        plt.scatter(X_transformed[0, -n_types:], X_transformed[1, -n_types:], c='black',
                    zorder=2, s=sizes)
    else:
        sizes = [Counter(colors)[i] * multiplier / n_samples for i in order]
        print(sizes)
        plt.scatter(X_transformed[0, -n_types:], X_transformed[1, -n_types:], c='black',
                zorder=2, s=sizes)
    plt.axis('tight')
    plt.savefig(f'./figures/{fname}.pdf')
    plt.show()
    plt.close()
    fig = plt.figure(figsize=figsize)

    ax = fig.add_subplot()
    colors = _adata.obs[color].values
    if type(colors[0]) == str:
        c = [color_dict[i] for i in colors]
    else:
        c = colors
    sns.kdeplot(X_df_data[0], X_df_data[1], cmap="Reds", shade=True, bw=.15)
    if type(sizes) == int:
        plt.scatter(X_transformed[0, -n_types:], X_transformed[1, -n_types:], c='black',
                    zorder=2, s=sizes)
    else:
        sizes = [Counter(colors)[i] * multiplier / n_samples for i in order]
        print(sizes)
        plt.scatter(X_transformed[0, -n_types:], X_transformed[1, -n_types:], c='black',
                    zorder=2, s=sizes)
    plt.axis('tight')
    plt.show()
    plt.close()

# %%
color_dict = {}
for i,c in enumerate(sorted(list(set(adata_small.obs['tumor'])))):
    if i == 7:     color_dict[c] = sns.color_palette('tab10')[9] #skip grey
    else:
        color_dict[c] = sns.color_palette('tab10',8)[i]
cmap = 'jet'
_archetype_diagram_no_arrows(adata_small, color_dict=color_dict,color='tumor',fname = 'tumor_archetype_space',
                        order = ['SCLC-Y','SCLC-A','SCLC-P','SCLC-N','SCLC-A2'], norm = 'None',
                        multiplier=1, figsize=(8,8), score_name = '_Score', alpha = .5, s = 4, sizes = 20)
# Out:
# Index(['SCLC-A_Score', 'SCLC-A2_Score', 'SCLC-P_Score'], dtype='object')

# %% [markdown]
# ## Newer phenotype classification with labeled generalists
# Let's check to see how many samples have significant scores (p>.3) for more than one phenotype.

# %%
df = adata.obs[[f"{x}_Score_pos" for x in ['SCLC-N', 'SCLC-A', 'SCLC-P', 'SCLC-Y', 'SCLC-A2']]]
# np.unique((df > .3).sum(axis = 1), return_counts=True)[1]
plt.bar(height = np.unique(((df.T/df.sum(axis = 1)).T > .33).sum(axis = 1), return_counts=True)[1], x = range(3), log=False)
# Out:
# <BarContainer object of 3 artists>

# %%
arc_pheno = []
arc_aa_type = []

for i,r in df.iterrows():
    r = r/r.sum()
    if (r > .33).sum() > 1:
        arc_aa_type.append('Generalist')
        arc_pheno.append(r.sort_values(ascending=False)[0:2].sort_index().index[0].split('_')[0]+"_"+r.sort_values(ascending=False)[0:2].sort_index().index[1].split('_')[0])
    elif  (r > .33).sum() == 1:
        try:
            arc_aa_type.append(r.idxmax().split('_')[0]+" Specialist")
            arc_pheno.append(r.idxmax().split('_')[0])
        except AttributeError: 
            arc_aa_type.append("Unclassified")
            arc_pheno.append("Unclassified")
    else: 
        arc_aa_type.append("Unclassified")
        arc_pheno.append("Unclassified")
adata.obs['arc_pheno'] = arc_pheno
adata.obs['arc_aa_type'] = arc_aa_type

# %%
pd.crosstab(adata.obs['arc_pheno'],adata.obs['tumor']).style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_92dac_row0_col0, #T_92dac_row14_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_92dac_row0_col1, #T_92dac_row4_col1, #T_92dac_row7_col1, #T_92dac_row11_col0, #T_92dac_row13_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_92dac_row1_col0 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_92dac_row1_col1 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_92dac_row2_col0 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_92dac_row2_col1, #T_92dac_row6_col1, #T_92dac_row15_col1 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_92dac_row3_col0 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_92dac_row3_col1 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_92dac_row4_col0, #T_92dac_row10_col1, #T_92dac_row13_col1 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_92dac_row5_col0 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_92dac_row5_col1, #T_92dac_row12_col1 {
#   background-color: #453781;
#   color: #f1f1f1;
# }
# #T_92dac_row6_col0, #T_92dac_row11_col1 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_92dac_row7_col0 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_92dac_row8_col0 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_92dac_row8_col1 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_92dac_row9_col0 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_92dac_row9_col1 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_92dac_row10_col0 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_92dac_row12_col0 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_92dac_row14_col0 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_92dac_row15_col0 {
#   background-color: #46327e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_92dac_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >tumor</th>
#       <th class="col_heading level0 col0" >Tumor 1</th>
#       <th class="col_heading level0 col1" >Tumor 2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >arc_pheno</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92dac_level0_row0" class="row_heading level0 row0" >SCLC-A</th>
#       <td id="T_92dac_row0_col0" class="data row0 col0" >478</td>
#       <td id="T_92dac_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row1" class="row_heading level0 row1" >SCLC-A2</th>
#       <td id="T_92dac_row1_col0" class="data row1 col0" >331</td>
#       <td id="T_92dac_row1_col1" class="data row1 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row2" class="row_heading level0 row2" >SCLC-A2_SCLC-A</th>
#       <td id="T_92dac_row2_col0" class="data row2 col0" >85</td>
#       <td id="T_92dac_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row3" class="row_heading level0 row3" >SCLC-A2_SCLC-N</th>
#       <td id="T_92dac_row3_col0" class="data row3 col0" >25</td>
#       <td id="T_92dac_row3_col1" class="data row3 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row4" class="row_heading level0 row4" >SCLC-A2_SCLC-P</th>
#       <td id="T_92dac_row4_col0" class="data row4 col0" >32</td>
#       <td id="T_92dac_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row5" class="row_heading level0 row5" >SCLC-A2_SCLC-Y</th>
#       <td id="T_92dac_row5_col0" class="data row5 col0" >11</td>
#       <td id="T_92dac_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row6" class="row_heading level0 row6" >SCLC-A_SCLC-N</th>
#       <td id="T_92dac_row6_col0" class="data row6 col0" >23</td>
#       <td id="T_92dac_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row7" class="row_heading level0 row7" >SCLC-A_SCLC-P</th>
#       <td id="T_92dac_row7_col0" class="data row7 col0" >109</td>
#       <td id="T_92dac_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row8" class="row_heading level0 row8" >SCLC-A_SCLC-Y</th>
#       <td id="T_92dac_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_92dac_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row9" class="row_heading level0 row9" >SCLC-N</th>
#       <td id="T_92dac_row9_col0" class="data row9 col0" >125</td>
#       <td id="T_92dac_row9_col1" class="data row9 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row10" class="row_heading level0 row10" >SCLC-N_SCLC-P</th>
#       <td id="T_92dac_row10_col0" class="data row10 col0" >16</td>
#       <td id="T_92dac_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row11" class="row_heading level0 row11" >SCLC-N_SCLC-Y</th>
#       <td id="T_92dac_row11_col0" class="data row11 col0" >4</td>
#       <td id="T_92dac_row11_col1" class="data row11 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row12" class="row_heading level0 row12" >SCLC-P</th>
#       <td id="T_92dac_row12_col0" class="data row12 col0" >151</td>
#       <td id="T_92dac_row12_col1" class="data row12 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row13" class="row_heading level0 row13" >SCLC-P_SCLC-Y</th>
#       <td id="T_92dac_row13_col0" class="data row13 col0" >5</td>
#       <td id="T_92dac_row13_col1" class="data row13 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row14" class="row_heading level0 row14" >SCLC-Y</th>
#       <td id="T_92dac_row14_col0" class="data row14 col0" >22</td>
#       <td id="T_92dac_row14_col1" class="data row14 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_92dac_level0_row15" class="row_heading level0 row15" >Unclassified</th>
#       <td id="T_92dac_row15_col0" class="data row15 col0" >71</td>
#       <td id="T_92dac_row15_col1" class="data row15 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab( adata.obs['arc_pheno'],adata.obs['Phenotype']).style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_42a77_row0_col0, #T_42a77_row0_col2, #T_42a77_row1_col1, #T_42a77_row1_col3, #T_42a77_row9_col4, #T_42a77_row14_col5 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_42a77_row0_col1 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_42a77_row0_col3, #T_42a77_row0_col4, #T_42a77_row0_col5, #T_42a77_row1_col2, #T_42a77_row1_col4, #T_42a77_row1_col5, #T_42a77_row2_col2, #T_42a77_row2_col3, #T_42a77_row2_col4, #T_42a77_row2_col5, #T_42a77_row3_col1, #T_42a77_row3_col2, #T_42a77_row3_col3, #T_42a77_row3_col4, #T_42a77_row3_col5, #T_42a77_row4_col2, #T_42a77_row4_col3, #T_42a77_row4_col4, #T_42a77_row4_col5, #T_42a77_row5_col2, #T_42a77_row5_col3, #T_42a77_row5_col4, #T_42a77_row5_col5, #T_42a77_row6_col2, #T_42a77_row6_col3, #T_42a77_row6_col4, #T_42a77_row6_col5, #T_42a77_row7_col2, #T_42a77_row7_col3, #T_42a77_row7_col4, #T_42a77_row7_col5, #T_42a77_row8_col1, #T_42a77_row8_col2, #T_42a77_row8_col3, #T_42a77_row8_col4, #T_42a77_row8_col5, #T_42a77_row9_col2, #T_42a77_row9_col3, #T_42a77_row9_col5, #T_42a77_row10_col2, #T_42a77_row10_col3, #T_42a77_row10_col4, #T_42a77_row10_col5, #T_42a77_row11_col1, #T_42a77_row11_col2, #T_42a77_row11_col3, #T_42a77_row11_col4, #T_42a77_row11_col5, #T_42a77_row12_col2, #T_42a77_row12_col3, #T_42a77_row12_col4, #T_42a77_row12_col5, #T_42a77_row13_col0, #T_42a77_row13_col2, #T_42a77_row13_col3, #T_42a77_row13_col4, #T_42a77_row13_col5, #T_42a77_row14_col1, #T_42a77_row14_col2, #T_42a77_row14_col3, #T_42a77_row14_col4, #T_42a77_row15_col0, #T_42a77_row15_col2, #T_42a77_row15_col3, #T_42a77_row15_col4, #T_42a77_row15_col5 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_42a77_row1_col0 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_42a77_row2_col0 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_42a77_row2_col1, #T_42a77_row13_col1 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_42a77_row3_col0 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_42a77_row4_col0 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_42a77_row4_col1 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_42a77_row5_col0, #T_42a77_row10_col0 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_42a77_row5_col1 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_42a77_row6_col0 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_42a77_row6_col1, #T_42a77_row10_col1 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_42a77_row7_col0 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_42a77_row7_col1 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_42a77_row8_col0 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_42a77_row9_col0 {
#   background-color: #39558c;
#   color: #f1f1f1;
# }
# #T_42a77_row9_col1 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_42a77_row11_col0 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_42a77_row12_col0 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_42a77_row12_col1 {
#   background-color: #efe51c;
#   color: #000000;
# }
# #T_42a77_row14_col0 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_42a77_row15_col1 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_42a77_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Phenotype</th>
#       <th class="col_heading level0 col0" >Generalist</th>
#       <th class="col_heading level0 col1" >None</th>
#       <th class="col_heading level0 col2" >SCLC-A</th>
#       <th class="col_heading level0 col3" >SCLC-A2</th>
#       <th class="col_heading level0 col4" >SCLC-N</th>
#       <th class="col_heading level0 col5" >SCLC-Y</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >arc_pheno</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42a77_level0_row0" class="row_heading level0 row0" >SCLC-A</th>
#       <td id="T_42a77_row0_col0" class="data row0 col0" >418</td>
#       <td id="T_42a77_row0_col1" class="data row0 col1" >26</td>
#       <td id="T_42a77_row0_col2" class="data row0 col2" >34</td>
#       <td id="T_42a77_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_42a77_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_42a77_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_42a77_level0_row1" class="row_heading level0 row1" >SCLC-A2</th>
#       <td id="T_42a77_row1_col0" class="data row1 col0" >288</td>
#       <td id="T_42a77_row1_col1" class="data row1 col1" >42</td>
#       <td id="T_42a77_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_42a77_row1_col3" class="data row1 col3" >18</td>
#       <td id="T_42a77_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_42a77_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_42a77_level0_row2" class="row_heading level0 row2" >SCLC-A2_SCLC-A</th>
#       <td id="T_42a77_row2_col0" class="data row2 col0" >81</td>
#       <td id="T_42a77_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_42a77_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_42a77_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_42a77_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_42a77_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_42a77_level0_row3" class="row_heading level0 row3" >SCLC-A2_SCLC-N</th>
#       <td id="T_42a77_row3_col0" class="data row3 col0" >29</td>
#       <td id="T_42a77_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_42a77_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_42a77_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_42a77_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_42a77_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_42a77_level0_row4" class="row_heading level0 row4" >SCLC-A2_SCLC-P</th>
#       <td id="T_42a77_row4_col0" class="data row4 col0" >26</td>
#       <td id="T_42a77_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_42a77_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_42a77_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_42a77_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_42a77_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_42a77_level0_row5" class="row_heading level0 row5" >SCLC-A2_SCLC-Y</th>
#       <td id="T_42a77_row5_col0" class="data row5 col0" >16</td>
#       <td id="T_42a77_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_42a77_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_42a77_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_42a77_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_42a77_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_42a77_level0_row6" class="row_heading level0 row6" >SCLC-A_SCLC-N</th>
#       <td id="T_42a77_row6_col0" class="data row6 col0" >20</td>
#       <td id="T_42a77_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_42a77_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_42a77_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_42a77_row6_col4" class="data row6 col4" >0</td>
#       <td id="T_42a77_row6_col5" class="data row6 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_42a77_level0_row7" class="row_heading level0 row7" >SCLC-A_SCLC-P</th>
#       <td id="T_42a77_row7_col0" class="data row7 col0" >99</td>
#       <td id="T_42a77_row7_col1" class="data row7 col1" >10</td>
#       <td id="T_42a77_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_42a77_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_42a77_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_42a77_row7_col5" class="data row7 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_42a77_level0_row8" class="row_heading level0 row8" >SCLC-A_SCLC-Y</th>
#       <td id="T_42a77_row8_col0" class="data row8 col0" >18

# %%
cp = ['#fc8d62', '#66c2a5', '#FFD43B', '#8da0cb', '#e78ac3']
color_dict = {'SCLC-Y Specialist': cp[4], 'SCLC-A Specialist': cp[0], 'SCLC-A2 Specialist': cp[1], 'SCLC-N Specialist': cp[2], 'SCLC-P Specialist': cp[3],
              'Generalist': 'darkgrey', 'Unclassified': 'lightgrey'}
mb.pl.subtype_bar(adata,groupby='tumor', fname = 'tumor', pheno_name="arc_aa_type", custom_palette=color_dict)

# %%
_adata = adata[adata.obs['arc_aa_type'] == 'Generalist']
plt.rcParams["figure.figsize"] = [8, 4]
((pd.crosstab(_adata.obs["tumor"], _adata.obs['arc_pheno']).T /
  pd.crosstab(_adata.obs["tumor"], _adata.obs['arc_pheno']).sum(axis=1)) * 100).T.plot(kind='bar',
                                                                                              stacked=True,
                                                                                              linewidth=0, cmap = 'Spectral')
plt.legend(bbox_to_anchor=(1.05, 1))

plt.savefig('./figures/arc_aa_generalist_subtypes.pdf')

# %%
# import matplotlib as mpl
# mpl.rcParams['figure.dpi']= 300
# mb.pl.archetype_diagrams(adata, sig_matrix, color_dict=color_dict, groupby='cline',color = 'arc_aa_type',
#                         order = ['SCLC-Y','SCLC-A','SCLC-P','SCLC-N','SCLC-A2'], norm = 'None',sizes = 20,
#                         figsize=(4,4), score_name = '_Score', alpha = .8, s = 8, arrows = False)

# %%
np.unique(adata.obs['arc_pheno'], return_counts=True)
# Out:
# (array(['SCLC-A', 'SCLC-A2', 'SCLC-A2_SCLC-A', 'SCLC-A2_SCLC-N',
#         'SCLC-A2_SCLC-P', 'SCLC-A2_SCLC-Y', 'SCLC-A_SCLC-N',
#         'SCLC-A_SCLC-P', 'SCLC-A_SCLC-Y', 'SCLC-N', 'SCLC-N_SCLC-P',
#         'SCLC-N_SCLC-Y', 'SCLC-P', 'SCLC-P_SCLC-Y', 'SCLC-Y',
#         'Unclassified'], dtype=object),
#  array([478, 348,  86,  30,  32,  19,  24, 109,  19, 137,  19,   6, 159,
#           8,  72,  72]))

# %%
adata.write_h5ad('../../out/human-tumors/adata_03.h5ad')
# Out:
# ... storing 'Phenotype' as categorical
# ... storing 'arc_pheno' as categorical
# ... storing 'arc_aa_type' as categorical

# %% [markdown]
# Keep in mind that the ternary plots are renormalized, so the cell labeled A2, for example, shows up in the middle of the plot because A, N, and Y are renormalized to sum to 1 even though A2 was the highest probability phenotype.

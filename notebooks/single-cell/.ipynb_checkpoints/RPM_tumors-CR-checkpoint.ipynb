# %% [markdown]
# # RPM Tumor Time Series Analysis

# %%
import scvelo as scv
import scanpy as sc
import os.path as op
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import cellrank as cr
sys.path.insert(1, "/Users/smgroves/Documents/GitHub/Groves-CellSys2021/")
import mazebox as mb

# %%
scv.settings.verbosity = 3
scv.settings.set_figure_params("scvelo")
cr.settings.verbosity = 2

# %%
import warnings

warnings.simplefilter("ignore", category=UserWarning)
warnings.simplefilter("ignore", category=FutureWarning)
warnings.simplefilter("ignore", category=DeprecationWarning)

# %%
# !pip install phate

# %% [markdown]
# ## Read in data
#
# This data comes from the end of the notebook `RPM_tumors.ipynb`

# %%
adata = cr.read('../out/RPM-time-series/adata06.h5ad')
# Out:
# /var/folders/vh/xk34gq593k53lzm7wlyg64xw0000gn/T/ipykernel_71863/2177919680.py:1: DeprecationWarning: `cellrank.tl.read` will be removed in version `2.0`. Please use the `cellrank.kernels` or `cellrank.estimators` interface instead.
#   adata = cr.read('../out/RPM-time-series/adata06.h5ad')

# %%
scv.pl.proportions(adata, groupby='timepoint')

# %% [markdown]
# ## Run scVelo

# %%
scv.tl.recover_dynamics(adata, n_jobs=8)
scv.tl.velocity(adata, mode="dynamical", vkey = 'dynamical')
scv.tl.velocity_graph(adata, )

# %%
scv.pl.velocity_embedding_stream(
    adata, basis="umap", legend_fontsize=12, title="", smooth=0.8, min_mass=4
)

# %% [markdown]
# # Run CellRank

# %% [markdown]
# ## Find initial and terminal states.
#
# I think it may be helpful here to:
#
# 1. Louvain/leiden cluster the samples.
# 2. Connect each cluster with each of our archetype signatures.
#     1. Otherwise, our archetype signatures are not finding clusters in umap space
# 3. Find end states in terms of the clusters, and then connect that with the archetypes through signatures.

# %%
scv.pl.velocity(adata, ['Ascl1',  'Notch1', 'Notch2', 'Notch3','Notch4'], ncols=2, color='timepoint')

# %%
scv.tl.recover_dynamics(adata, var_names=['Ascl1',  'Notch1', 'Notch2', 'Notch3','Notch4'])

# top_genes = adata.var['fit_likelihood'].sort_values(ascending=False).index

# scv.pl.scatter(adata, basis=top_genes[:15], ncols=5, frameon=False)
# Out:
# recovering dynamics (using 1/16 cores)
#     finished (0:00:27) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)

# %%
scv.pl.scatter(adata, basis=['Ascl1',  'Notch1', 'Notch2', 'Notch3','Notch4'], ncols=5, frameon=False, color = 'timepoint')

# %%
var_names = ['Ascl1',  'Notch1', 'Notch2', 'Notch3','Notch4']
scv.tl.differential_kinetic_test(adata, var_names=var_names, groupby='timepoint')
# Out:
# testing for differential kinetics
#     finished (0:00:02) --> added
#     'fit_diff_kinetics', clusters displaying differential kinetics (adata.var)
#     'fit_pvals_kinetics', p-values of differential kinetics (adata.var)

# %%
adata.var
# Out:
#                    Accession Chromosome        End      Start Strand  \
# Rplp1     ENSMUSG00000007892          9   61914542   61913284      -
# Rps8      ENSMUSG00000047675          4  117156243  117153827      -
# Ftl1      ENSMUSG00000050708          7   45459884   45457944      -
# Rplp2     ENSMUSG00000025508          7  141451585  141447370      +
# Hsp90ab1  ENSMUSG00000023944         17   45573271   45567775      -
# ...                      ...        ...        ...        ...    ...
# Nr0b1     ENSMUSG00000025056          X   86195947   86191764      +
# Sox1      ENSMUSG00000096014          8   12400126   12395295      +
# Chat      ENSMUSG00000021919         14   32465989   32408203      -
# Neurod1   ENSMUSG00000034701          2   79456751   79452521      -
# Olig2     ENSMUSG00000039830         16   91228677   91225457      +
#
#           dropkick_coef-day_11  dropkick_coef-day_14  dropkick_coef-day_17  \
# Rplp1                      NaN                   NaN                   NaN
# Rps8                       NaN                   NaN                   NaN
# Ftl1                       NaN                   NaN                   0.0
# Rplp2                      NaN                   NaN                   NaN
# Hsp90ab1                   NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# Nr0b1                      NaN                   NaN                   NaN
# Sox1                       NaN                   NaN                   NaN
# Chat                       NaN                   NaN                   NaN
# Neurod1                    NaN                   NaN                   NaN
# Olig2                      NaN                   NaN                   NaN
#
#           dropkick_coef-day_21  dropkick_coef-0-day_4  ...  fit_likelihood  \
# Rplp1                      NaN                    NaN  ...             NaN
# Rps8                       NaN                    NaN  ...             NaN
# Ftl1                      0.03                    NaN  ...             NaN
# Rplp2                      NaN                    NaN  ...             NaN
# Hsp90ab1                   NaN                    NaN  ...             NaN
# ...                        ...                    ...  ...             ...
# Nr0b1                      NaN                    NaN  ...             NaN
# Sox1                       NaN                    NaN  ...             NaN
# Chat                       NaN                    NaN  ...             NaN
# Neurod1                    NaN                    NaN  ...             NaN
# Olig2                      NaN                    NaN  ...             NaN
#
#           fit_u0  fit_s0  fit_pval_steady  fit_steady_u  fit_steady_s  \
# Rplp1        NaN     NaN              NaN           NaN           NaN
# Rps8         NaN     NaN              NaN           NaN           NaN
# Ftl1         NaN     NaN              NaN           NaN           NaN
# Rplp2        NaN     NaN              NaN           NaN           NaN
# Hsp90ab1     NaN     NaN              NaN           NaN           NaN
# ...          ...     ...              ...           ...           ...
# Nr0b1        NaN     NaN              NaN           NaN           NaN
# Sox1         NaN     NaN              NaN           NaN           NaN
# Chat         NaN     NaN              NaN           NaN           NaN
# Neurod1      NaN     NaN              NaN           NaN           NaN
# Olig2        NaN     NaN              NaN           NaN           NaN
#
#           fit_variance  fit_alignment_scaling  fit_diff_kinetics  \
# Rplp1              NaN                    NaN               None
# Rps8               NaN                    NaN               None
# Ftl1               NaN                    NaN               None
# Rplp2              NaN                    NaN               None
# Hsp90ab1           NaN                    NaN               None
# ...                ...                    ...                ...
# Nr0b1              NaN                    NaN               None
# Sox1               NaN                    NaN               None
# Chat               NaN                    NaN               None
# Neurod1            NaN                    NaN               None
# Olig2              NaN                    NaN               None
#
#           fit_pval_kinetics
# Rplp1                   NaN
# Rps8                    NaN
# Ftl1                    NaN
# Rplp2                   NaN
# Hsp90ab1                NaN
# ...                     ...
# Nr0b1                   NaN
# Sox1                    NaN
# Chat                    NaN
# Neurod1                 NaN
# Olig2                   NaN
#
# [21163 rows x 45 columns]

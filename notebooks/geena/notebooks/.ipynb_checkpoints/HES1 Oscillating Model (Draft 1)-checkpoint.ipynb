# %%
from pysb.core import *
from pysb.integrate import *
import matplotlib.pyplot as plt
import numpy as np
from pysb.integrate import ScipyOdeSimulator as SOS
from pysb.bng import generate_equations

Model()
Monomer('NOTCH3', ['dll4', 'jag2'])
Monomer('DLL4', ['notch3'])
Monomer('JAG2', ['notch3'])
Monomer('NICD', ['rbpj'])
Monomer('RBPJ', ['nicd'])
Monomer('HES1', ['dimer'])
Monomer('DIMER', ['hes1'])
Monomer('HCM', ['e'])
Monomer('HNP', ['hes6'])
Monomer ('HES6', ['hnp'])
Monomer ('ENZM', ['m'])

Parameter('kf', 1e-2)
Parameter('kr', 1e-4)
Parameter('kc', 1)
Parameter('NOTCH3_0', 270)
Parameter('JAG2_0', 1500)
Parameter('DLL4_0', 2000)
Parameter('NICD_0', 0)
Parameter('RBPJ_0', 430)
Parameter('DIMER_0', 0)
Parameter('HES1_0', 1)
Parameter('HCM_0', 1)
Parameter('HNP_0', 130)
Parameter('HES6_0', 50)
Parameter('ENZM_0', 50)

Initial(NOTCH3(dll4 = None, jag2 = None), NOTCH3_0)
Initial(JAG2(notch3 = None), JAG2_0)
Initial(DLL4(notch3 = None),DLL4_0)
Initial(NICD(rbpj = None),NICD_0)
Initial(RBPJ(nicd = None),RBPJ_0)
Initial(HES1(dimer = None),HES1_0)
Initial(DIMER(hes1 = None),DIMER_0)
Initial(HCM(e = None),HCM_0)
Initial(HNP(hes6 = None),HNP_0)
Initial(HES6(hnp = None),HES6_0)
Initial(ENZM(m = None),ENZM_0)        
        
    
        
Rule('jag_binds_notch', JAG2(notch3 = None) + NOTCH3(dll4 = None, jag2 = None) |
     JAG2(notch3 = 1) % NOTCH3(dll4 = None, jag2 = 1), kf, kr)
Rule('dll_binds_notch', DLL4(notch3 = None) + NOTCH3(dll4 = None, jag2 = None) |
     DLL4(notch3 = 1) % NOTCH3(dll4 = 1, jag2 = None), kf, kr)

Rule('nicd_catalysis_j', JAG2(notch3 = 1) % NOTCH3(dll4 = None, jag2 = 1) >> NOTCH3(dll4 = None, jag2 = None) + JAG2(notch3 = None) + NICD(rbpj = None), kc)
Rule('nicd_catalysis_d', DLL4(notch3 = 1) % NOTCH3(dll4 = 1, jag2 = None) >> NOTCH3(dll4 = None, jag2 = None) + DLL4(notch3 = None) + NICD(rbpj = None), kc)

        
Rule('nicd_binds_rbpj', NICD(rbpj = None) + RBPJ(nicd = None) >> DIMER(hes1 = None) + NICD(rbpj = None) + RBPJ(nicd = None), kc)
Rule('hes1_activation', HES1(dimer = None) + DIMER(hes1 = None) |
     HES1(dimer = 1) % DIMER(hes1 = 1), kf, kr)


Rule('hcm_synth', HES1(dimer = None) >> HCM(e = None) + HES1(dimer = None), kf)
Rule('hnp_synth', HCM(e = None) >> HCM(e = None) + HNP(hes6 = None), kf)

Rule('hcm_deg_complex', HCM(e = None) + ENZM(m = None) |
     HCM(e = 1) % ENZM(m = 1), kf, kr)
Rule('hcm_deg', HCM(e = 1) % ENZM (m = 1) >> ENZM(m = None), kf)

Rule('hnp_deg_complex', HNP(hes6 = None) + HES6(hnp = None) |
     HNP(hes6 = 1) % HES6(hnp = 1), kf, kr)
Rule('hnp_deg', HNP(hes6 = 1) % HES6 (hnp = 1) >> HES6(hnp = None), kf)


Observable('mRNA_obs', HCM())
Observable('Protein_obs', HNP())

generate_equations(model, verbose = True)

print
for sp in model.species:
    print(sp)

tspan = np.linspace(0, 50, 1001)
sim1 = SOS(model, tspan, verbose=True)
sim_result = sim1.run()
plt.plot(tspan, sim_result.observables['mRNA_obs'], lw=2, label='mRNA')
plt.plot(tspan, sim_result.observables['Protein_obs'], lw=2, label='Protein')
plt.xlabel("Time")
plt.ylabel("Molecules")
plt.legend(loc=0)
plt.show()
# Out:
# 2021-11-16 18:26:08.226 - pysb.bng - DEBUG - [_interactive_] <class 'pysb.bng.BngFileInterface'> instantiated in directory /var/folders/v0/vt_8cr9j5lv7f_l76ck5djkh0000gn/T/tmpBNGbetb3fxt
# 2021-11-16 18:26:08.227 - pysb.bng - INFO - [_interactive_] Generating reaction network
# 2021-11-16 18:26:08.230 - pysb.bng - DEBUG - [_interactive_] BNG command file contents:
# L01  begin model
# L02  begin parameters
# L03    kf         0.01
# L04    kr         0.0001
# L05    kc         1
# L06    NOTCH3_0   270
# L07    JAG2_0     1500
# L08    DLL4_0     2000
# L09    NICD_0     0
# L10    RBPJ_0     430
# L11    DIMER_0    0
# L12    HES1_0     1
# L13    HCM_0      1
# L14    HNP_0      130
# L15    HES6_0     50
# L16    ENZM_0     50
# L17  end parameters
# L18
# L19  begin molecule types
# L20    NOTCH3(dll4,jag2)
# L21    DLL4(notch3)
# L22    JAG2(notch3)
# L23    NICD(rbpj)
# L24    RBPJ(nicd)
# L25    HES1(dimer)
# L26    DIMER(hes1)
# L27    HCM(e)
# L28    HNP(hes6)
# L29    HES6(hnp)
# L30    ENZM(m)
# L31  end molecule types
# L32
# L33  begin observables
# L34    Molecules mRNA_obs      HCM()
# L35    Molecules Protein_obs   HNP()
# L36  end observables
# L37
# L38  begin species
# L39    NOTCH3(dll4,jag2)   NOTCH3_0
# L40    JAG2(notch3)        JAG2_0
# L41    DLL4(notch3)        DLL4_0
# L42    NICD(rbpj)          NICD_0
# L43    RBPJ(nicd)          RBPJ_0
# L44    HES1(dimer)         HES1_0
# L45    DIMER(hes1)         DIMER_0
# L46    HCM(e)              HCM_0
# L47    HNP(hes6)           HNP_0
# L48    HES6(hnp)           HES6_0
# L49    ENZM(m)             ENZM_0
# L50  end species
# L51
# L52  begin reaction rules
# L53    jag_binds_notch:   JAG2(notch3) + NOTCH3(dll4,jag2) <-> JAG2(notch3!1).NOTCH3(dll4,jag2!1)    kf, kr
# L54    dll_binds_notch:   DLL4(notch3) + NOTCH3(dll4,jag2) <-> DLL4(notch3!1).NOTCH3(dll4!1,jag2)    kf, kr
# L55    nicd_catalysis_j:  JAG2(notch3!1).NOTCH3(dll4,jag2!1) -> NOTCH3(dll4,jag2) + JAG2(notch3) + NICD(rbpj)    kc
# L56    nicd_catalysis_d:  DLL4(notch3!1).NOTCH3(dll4!1,jag2) -> NOTCH3(dll4,jag2) + DLL4(notch3) + NICD(rbpj)    kc
# L57    nicd_binds_rbpj:   NICD(rbpj) + RBPJ(nicd) -> DIMER(hes1) + NICD(rbpj) + RBPJ(nicd)    kc
# L58    hes1_activation:   HES1(dimer) + DIMER(hes1) <-> HES1(dimer!1).DIMER(hes1!1)    kf, kr
# L59    hcm_synth:         HES1(dimer) -> HCM(e) + HES1(dimer)    kf
# L60    hnp_synth:         HCM(e) -> HCM(e) + HNP(hes6)    kf
# L61    hcm_deg_complex:   HCM(e) + ENZM(m) <-> HCM(e!1).ENZM(m!1)    kf, kr
# L62    hcm_deg:           HCM(e!1).ENZM(m!1) -> ENZM(m)    kf
# L63    hnp_deg_complex:   HNP(hes6) + HES6(hnp) <-> HNP(hes6!1).HES6(hnp!1)    kf, kr
# L64    hnp_deg:           HNP(hes6!1).HES6(hnp!1) -> HES6(hnp)    kf
# L65  end reaction rules
# L66
# L67  end model
# L68  begin actions
# L69  	generate_network({overwrite=>1,verbose=>1})
# L70  end actions
# L71
# 2021-11-16 18:26:08.668 - pysb.bng - DEBUG - [_interactive_] BioNetGen version 2.5.1
# 2021-11-16 18:26:08.672 - pysb.bng - DEBUG - [_interactive_] Reading from file /var/folders/v0/vt_8cr9j5lv7f_l76ck5djkh0000gn/T/tmpBNGbetb3fxt/pysb.bngl (level 0)
# 2021-11-16 18:26:08.673 - pysb.bng - DEBUG - [_interactive_] Read 14 parameters.
# 2021-11-16 18:26:08.674 - pysb.bng - DEBUG - [_interactive_] Read 11 molecule types.
# 2021-11-16 18:26:08.675 - pysb.bng - DEBUG - [_interactive_] Read 2 observable(s).
# 2021-11-16 18:26:08.677 - pysb.bng - DEBUG - [_interactive_] Read 11 species.
# 2021-11-16 18:26:08.720 - pysb.bng - DEBUG - [_interactive_] Read 12 reaction rule(s).
# 2021-11-16 18:26:08.721 - pysb.bng - DEBUG - [_interactive_] ACTION: generate_network( pysb )
# 2021-11-16 18:26:08.723 - pysb.bng - DEBUG - [_interactive_] Iteration   0:    11 species      0 rxns  0.00e+00 CPU s
# 2021-11-16 18:26:08.728 - pysb.bng - DEBUG - [_interactive_] Rule 1:
# 2021-11-16 18:26:08.732 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.733 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 2
# 2021-11-16 18:26:08.734 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.737 - pysb.bng - DEBUG - [_interactive_]   reverse:
# 2021-11-16 18:26:08.739 - pysb.bng - DEBUG - [_interactive_]       ..found 0 new matches to reactant pattern 1
# 2021-11-16 18:26:08.741 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.743 - pysb.bng - DEBUG - [_interactive_] Rule 2:
# 2021-11-16 18:26:08.745 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.747 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 2
# 2021-11-16 18:26:08.749 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.751 - pysb.bng - DEBUG - [_interactive_]   reverse:
# 2021-11-16 18:26:08.753 - pysb.bng - DEBUG - [_interactive_]       ..found 0 new matches to reactant pattern 1
# 2021-11-16 18:26:08.754 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 1.00e-02 CPU s
# 2021-11-16 18:26:08.756 - pysb.bng - DEBUG - [_interactive_] Rule 3:
# 2021-11-16 18:26:08.758 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.762 - pysb.bng - DEBUG - [_interactive_]       ..found 0 new matches to reactant pattern 1
# 2021-11-16 18:26:08.764 - pysb.bng - DEBUG - [_interactive_] Result:     0 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.768 - pysb.bng - DEBUG - [_interactive_] Rule 4:
# 2021-11-16 18:26:08.775 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.781 - pysb.bng - DEBUG - [_interactive_]       ..found 0 new matches to reactant pattern 1
# 2021-11-16 18:26:08.786 - pysb.bng - DEBUG - [_interactive_] Result:     0 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.789 - pysb.bng - DEBUG - [_interactive_] Rule 5:
# 2021-11-16 18:26:08.791 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.793 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 2
# 2021-11-16 18:26:08.796 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.799 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.802 - pysb.bng - DEBUG - [_interactive_] Rule 6:
# 2021-11-16 18:26:08.804 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.805 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 2
# 2021-11-16 18:26:08.807 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.809 - pysb.bng - DEBUG - [_interactive_]   reverse:
# 2021-11-16 18:26:08.812 - pysb.bng - DEBUG - [_interactive_]       ..found 0 new matches to reactant pattern 1
# 2021-11-16 18:26:08.813 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.816 - pysb.bng - DEBUG - [_interactive_] Rule 7:
# 2021-11-16 18:26:08.817 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.819 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.820 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 1.00e-02 CPU s
# 2021-11-16 18:26:08.822 - pysb.bng - DEBUG - [_interactive_] Rule 8:
# 2021-11-16 18:26:08.823 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.825 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.827 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.829 - pysb.bng - DEBUG - [_interactive_] Rule 9:
# 2021-11-16 18:26:08.830 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.832 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 2
# 2021-11-16 18:26:08.834 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.835 - pysb.bng - DEBUG - [_interactive_]   reverse:
# 2021-11-16 18:26:08.837 - pysb.bng - DEBUG - [_interactive_]       ..found 0 new matches to reactant pattern 1
# 2021-11-16 18:26:08.838 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.840 - pysb.bng - DEBUG - [_interactive_] Rule 10:
# 2021-11-16 18:26:08.841 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.842 - pysb.bng - DEBUG - [_interactive_]       ..found 0 new matches to reactant pattern 1
# 2021-11-16 18:26:08.844 - pysb.bng - DEBUG - [_interactive_] Result:     0 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.845 - pysb.bng - DEBUG - [_interactive_] Rule 11:
# 2021-11-16 18:26:08.847 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.849 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 2
# 2021-11-16 18:26:08.851 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.852 - pysb.bng - DEBUG - [_interactive_]   reverse:
# 2021-11-16 18:26:08.854 - pysb.bng - DEBUG - [_interactive_]       ..found 0 new matches to reactant pattern 1
# 2021-11-16 18:26:08.856 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 1.00e-02 CPU s
# 2021-11-16 18:26:08.857 - pysb.bng - DEBUG - [_interactive_] Rule 12:
# 2021-11-16 18:26:08.859 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.861 - pysb.bng - DEBUG - [_interactive_]       ..found 0 new matches to reactant pattern 1
# 2021-11-16 18:26:08.862 - pysb.bng - DEBUG - [_interactive_] Result:     0 new reactions 1.00e-02 CPU s
# 2021-11-16 18:26:08.864 - pysb.bng - DEBUG - [_interactive_] Iteration   1:    16 species      8 rxns  4.00e-02 CPU s
# 2021-11-16 18:26:08.865 - pysb.bng - DEBUG - [_interactive_] Rule 1:
# 2021-11-16 18:26:08.867 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.868 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 2
# 2021-11-16 18:26:08.869 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.870 - pysb.bng - DEBUG - [_interactive_]   reverse:
# 2021-11-16 18:26:08.871 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.873 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.874 - pysb.bng - DEBUG - [_interactive_] Rule 2:
# 2021-11-16 18:26:08.876 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.877 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 2
# 2021-11-16 18:26:08.878 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.879 - pysb.bng - DEBUG - [_interactive_]   reverse:
# 2021-11-16 18:26:08.880 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.882 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.883 - pysb.bng - DEBUG - [_interactive_] Rule 3:
# 2021-11-16 18:26:08.885 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.886 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.887 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 1.00e-02 CPU s
# 2021-11-16 18:26:08.888 - pysb.bng - DEBUG - [_interactive_] Rule 4:
# 2021-11-16 18:26:08.889 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.890 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.892 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.893 - pysb.bng - DEBUG - [_interactive_] Rule 5:
# 2021-11-16 18:26:08.894 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.895 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 2
# 2021-11-16 18:26:08.896 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.897 - pysb.bng - DEBUG - [_interactive_] Result:     0 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.899 - pysb.bng - DEBUG - [_interactive_] Rule 6:
# 2021-11-16 18:26:08.900 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.902 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 2
# 2021-11-16 18:26:08.904 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.905 - pysb.bng - DEBUG - [_interactive_]   reverse:
# 2021-11-16 18:26:08.907 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.909 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.911 - pysb.bng - DEBUG - [_interactive_] Rule 7:
# 2021-11-16 18:26:08.912 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.913 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.915 - pysb.bng - DEBUG - [_interactive_] Result:     0 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.916 - pysb.bng - DEBUG - [_interactive_] Rule 8:
# 2021-11-16 18:26:08.918 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.919 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.921 - pysb.bng - DEBUG - [_interactive_] Result:     0 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.923 - pysb.bng - DEBUG - [_interactive_] Rule 9:
# 2021-11-16 18:26:08.927 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.928 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 2
# 2021-11-16 18:26:08.930 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.932 - pysb.bng - DEBUG - [_interactive_]   reverse:
# 2021-11-16 18:26:08.933 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.935 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 1.00e-02 CPU s
# 2021-11-16 18:26:08.937 - pysb.bng - DEBUG - [_interactive_] Rule 10:
# 2021-11-16 18:26:08.938 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.939 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.942 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.943 - pysb.bng - DEBUG - [_interactive_] Rule 11:
# 2021-11-16 18:26:08.945 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.947 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 2
# 2021-11-16 18:26:08.950 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.951 - pysb.bng - DEBUG - [_interactive_]   reverse:
# 2021-11-16 18:26:08.953 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.954 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 0.00e+00 CPU s
# 2021-11-16 18:26:08.956 - pysb.bng - DEBUG - [_interactive_] Rule 12:
# 2021-11-16 18:26:08.958 - pysb.bng - DEBUG - [_interactive_]   forward:
# 2021-11-16 18:26:08.960 - pysb.bng - DEBUG - [_interactive_]       ..found 1 new match to reactant pattern 1
# 2021-11-16 18:26:08.962 - pysb.bng - DEBUG - [_interactive_] Result:     1 new reactions 1.00e-02 CPU s
# 2021-11-16 18:26:08.964 - pysb.bng - DEBUG - [_interactive_] Iteration   2:    16 species     17 rxns  3.00e-02 CPU s
# 2021-11-16 18:26:08.965 - pysb.bng - DEBUG - [_interactive_] Cumulative CPU time for each rule
# 2021-11-16 18:26:08.969 - pysb.bng - DEBUG - [_interactive_] Rule   1:     2 reactions 0.00e+00 CPU s 0.00e+00 CPU s/rxn
# 2021-11-16 18:26:08.973 - pysb.bng - DEBUG - [_interactive_] Rule   2:     2 reactions 1.00e-02 CPU s 5.00e-03 CPU s/rxn
# 2021-11-16 18:26:08.975 - pysb.bng - DEBUG - [_interactive_] Rule   3:     1 reactions 1.00e-02 CPU s 1.00e-02 CPU s/rxn
# 2021-11-16 18:26:08.977 - pysb.bng - DEBUG - [_interactive_] Rule   4:     1 reactions 0.00e+00 CPU s 0.00e+00 CPU s/rxn
# 2021-11-16 18:26:08.978 - pysb.bng - DEBUG - [_interactive_] Rule   5:     1 reactions 0.00e+00 CPU s 0.00e+00 CPU s/rxn
# 2021-11-16 18:26:08.980 - pysb.bng - DEBUG - [_interactive_] Rule   6:     2 reactions 0.00e+00 CPU s 0.00e+00 CPU s/rxn
# 2021-11-16 18:26:08.981 - pysb.bng - DEBUG - [_interactive_] Rule   7:     1 reactions 1.00e-02 CPU s 1.00e-02 CPU s/rxn
# 2021-11-16 18:26:08.983 - pysb.bng - DEBUG - [_interactive_] Rule   8:     1 reactions 0.00e+00 CPU s 0.00e+00 CPU s/rxn
# 2021-11-16 18:26:08.985 - pysb.bng - DEBUG - [_interactive_] Rule   9:     2 reactions 1.00e-02 CPU s 5.00e-03 CPU s/rxn
# 2021-11-16 18:26:08.986 - pysb.bng - DEBUG - [_interactive_] Rule  10:     1 reactions 0.00e+00 CPU s 0.00e+00 CPU s/rxn
# 2021-11-16 18:26:08.988 - pysb.bng - DEBUG - [_interactive_] Rule  11:     2 reactions 1.00e-02 CPU s 5.00e-03 CPU s/rxn
# 2021-11-16 18:26:08.990 - pysb.bng - DEBUG - [_interactive_] Rule  12:     1 reactions 2.00e-02 CPU s 2.00e-02 CPU s/rxn
# 2021-11-16 18:26:08.991 - pysb.bng - DEBUG - [_interactive_] Total   :    17 reactions 7.00e-02 CPU s 4.12e-03 CPU s/rxn
# 2021-11-16 18:26:08.993 - pysb.bng - DEBUG - [_interactive_] Wrote network in net format to ./pysb.net.
# 2021-11-16 18:26:08.994 - pysb.bng - DEBUG - [_interactive_] CPU TIME: generate_network 0.07 s.
# 2021-11-16 18:26:08.996 - pysb.bng - DEBUG - [_interactive_] Finished processing file /var/folders/v0/vt_8cr9j5lv7f_l76ck5djkh0000gn/T/tmpBNGbetb3fxt/pysb.bngl.
# 2021-11-16 18:26:08.998 - pysb.bng - DEBUG - [_interactive_] CPU TIME: total 0.12 s.
# 2021-11-16 18:26:09.001 - pysb.bng - DEBUG - [_interactive_] Reading BNG netfile: /var/folders/v0/vt_8cr9j5lv7f_l76ck5djkh0000gn/T/tmpBNGbetb3fxt/pysb.net
# 2021-11-16 18:26:09.281 - pysb.simulator.scipyode - DEBUG - [_interactive_] Simulator created
# 2021-11-16 18:26:09.284 - pysb.simulator.scipyode - WARNING - [_interactive_] This system of ODEs will be evaluated in pure Python. This may be slow for large models. We recommend installing the 'cython' package for compiling the ODEs to C code. This warning can be suppressed by specifying compiler='python'.
# 2021-11-16 18:26:09.285 - pysb.simulator.scipyode - DEBUG - [_interactive_] Using RhsBuilder: PythonRhsBuilder
# 2021-11-16 18:26:09.417 - pysb.simulator.scipyode - INFO - [_interactive_] Simulation(s) started
# 2021-11-16 18:26:09.452 - pysb.simulator.scipyode - DEBUG - [_interactive_] Single processor (serial) mode
# 2021-11-16 18:26:09.463 - pysb.simulator.scipyode - DEBUG - [_interactive_] Constructing rhs function
# NOTCH3(dll4=None, jag2=None)
# JAG2(notch3=None)
# DLL4(notch3=None)
# NICD(rbpj=None)
# RBPJ(nicd=None)
# HES1(dimer=None)
# DIMER(hes1=None)
# HCM(e=None)
# HNP(hes6=None)
# HES6(hnp=None)
# ENZM(m=None)
# JAG2(notch3=1) % NOTCH3(dll4=None, jag2=1)
# DLL4(notch3=1) % NOTCH3(dll4=1, jag2=None)
# DIMER(hes1=1) % HES1(dimer=1)
# ENZM(m=1) % HCM(e=1)
# HES6(hnp=1) % HNP(hes6=1)
# 2021-11-16 18:26:09.532 - pysb.simulator.scipyode - DEBUG - [_interactive_] Constructing constant expressions function
# 2021-11-16 18:26:09.684 - pysb.simulator.scipyode - INFO - [_interactive_] All simulation(s) complete
# 2021-11-16 18:26:09.685 - pysb.simulator.scipyode - DEBUG - [_interactive_] SimulationResult constructor started
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/v0/vt_8cr9j5lv7f_l76ck5djkh0000gn/T/ipykernel_5279/113825535.py in <module>
#      85 tspan = np.linspace(0, 50, 1001)
#      86 sim1 = SOS(model, tspan, verbose=True)
# ---> 87 sim_result = sim1.run()
#      88 plt.plot(tspan, sim_result.observables['mRNA_obs'], lw=2, label='mRNA')
#      89 plt.plot(tspan, sim_result.observables['Protein_obs'], lw=2, label='Protein')
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/site-packages/pysb/simulator/scipyode.py in run(self, tspan, initials, param_values, num_processors)
#     230         tout = np.array([self.tspan] * n_sims)
#     231         self._logger.info('All simulation(s) complete')
# --> 232         return SimulationResult(self, tout, trajectories)
#     233
#     234
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/site-packages/pysb/simulator/base.py in __init__(self, simulator, tout, trajectories, observables_and_expressions, squeeze, simulations_per_param_set, model, initials, param_values)
#     736                 # Network free simulations don't have initials list, only dict
#     737                 self._initials = simulator.initials_dict.copy()
# --> 738             self._model = copy.deepcopy(simulator._model)
#     739             self.simulator_class = simulator.__class__
#     740             self.init_kwargs = copy.deepcopy(simulator._init_kwargs)
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/copy.py in _deepcopy_list(x, memo, deepcopy)
#     203     append = y.append
#     204     for a in x:
# --> 205         append(deepcopy(a, memo))
#     206     return y
#     207 d[list] = _deepcopy_list
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     262     if deep and args:
#     263         args = (deepcopy(arg, memo) for arg in args)
# --> 264     y = func(*args)
#     265     if deep:
#     266         memo[id(x)] = y
#
# /Applications/anaconda3/envs/notch_env/lib/python3.9/copyreg.py in __newobj_ex__(cls, args, kwargs)
#      99     keyword-only arguments to be pickled correctly.
#     100     """
# --> 101     return cls.__new__(cls, *args, **kwargs)
#     102
#     103 def _slotnames(cls):
#
# TypeError: __new__() got an unexpected keyword argument 'real'

# %%
tspan = np.linspace(0, 50, 1001)
sim1 = SOS(model, tspan, verbose=True)
sim_result = sim1.run()
plt.plot(tspan, sim_result.observables['mRNA_obs'], lw=2, label='mRNA')
plt.plot(tspan, sim_result.observables['Protein_obs'], lw=2, label='Protein')
plt.xlabel("Time")
plt.ylabel("Molecules")
plt.legend(loc=0)
plt.show()
